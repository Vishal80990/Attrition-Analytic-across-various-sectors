# %%
import numpy as np
import pandas as pd

# %%
from refractio import snowflake
snowflake.get_connection(connection_name="DATA_HR_5K")
# Out:
# Connection manager service url initialised to http://fdc-project-manager:80/project-manager
# If you need to update its value then update the variable CONNECTION_MANAGER_BASE_URL in os env.
# Exception occurred in getting snowflake connection: 'connectionSources'

# %%
df = snowflake.get_dataframe("DATA_HR_5K")
df
# Out:
#          SALARY  SENIORITY  TENUREMONTHS  MONTHSAFTERCOLLEGE  BIRTHYEAR  \
# 0     37806.933          1            88                   3       1983
# 1     39922.660          1             7                  13       1995
# 2     29633.849          1            25                  11       1991
# 3     28482.500          1             9                  19       1986
# 4     67760.967          1            34                  60       1989
# ...         ...        ...           ...                 ...        ...
# 5361  68221.027          3             8                 116       1984
# 5362  25545.219          1            32                 150       1973
# 5363  49630.176          1            26                   9       1997
# 5364  38764.382          1            10                  44       1987
# 5365  78421.755          1            41                 120       1986
#
#      MAPPEDROLECLEAN SEX ETHNICITY          HOSPITALTYPE  \
# 0             social   F     White           Psychiatric
# 1              nurse   F     White  Acute Care Hospitals
# 2              nurse   F     White  Acute Care Hospitals
# 3              nurse   F     Black  Acute Care Hospitals
# 4                emt   M  Multiple  Acute Care Hospitals
# ...              ...  ..       ...                   ...
# 5361           nurse   F     White  Acute Care Hospitals
# 5362           nurse   M     White  Acute Care Hospitals
# 5363             emt   M  Hispanic  Acute Care Hospitals
# 5364           nurse   F     White  Acute Care Hospitals
# 5365           nurse   F     Black             Childrens
#
#                    HOSPITALOWNERSHIP  \
# 0     Voluntary non-profit - Private
# 1                        Proprietary
# 2      Voluntary non-profit - Church
# 3     Voluntary non-profit - Private
# 4      Voluntary non-profit - Church
# ...                              ...
# 5361   Voluntary non-profit - Church
# 5362                       Physician
# 5363                     Proprietary
# 5364                       Physician
# 5365    Voluntary non-profit - Other
#
#                                            COMPANYNAME      CITYSTATE  \
# 0     Adventist Health System Sunbelt Healthcare Corp.    Orlando, FL
# 1                               Tenet Healthcare Corp.    Modesto, CA
# 2                                          Mayo Clinic  Rochester, MN
# 3     Adventist Health System Sunbelt Healthcare Corp.      Tampa, FL
# 4     Adventist Health System Sunbelt Healthcare Corp.    Killeen, TX
# ...                                                ...            ...
# 5361                                       Mayo Clinic  Rochester, MN
# 5362                                       Mayo Clinic    Phoenix, AZ
# 5363                            Tenet Healthcare Corp.    Modesto, CA
# 5364                            Tenet Healthcare Corp.    Phoenix, AZ
# 5365                                  Cleveland Clinic  Cleveland, OH
#
#      DISTANCE               DEGREECLEAN SCHOOLENDDATE JOBSTARTDATE  \
# 0        <2mi            Masters Degree    31-01-2008   01-04-2008
# 1        <2mi          Bachelors Degree    01-01-2020   01-02-2021
# 2        <2mi                     Other    01-01-2015   01-12-2015
# 3      5-10mi          Bachelors Degree    01-01-2011   01-08-2012
# 4       2-5mi  Professional Certificate    01-01-2013   01-01-2018
# ...       ...                       ...           ...          ...
# 5361    >10mi            Masters Degree    31-01-2011   01-09-2020
# 5362    2-5mi                     Other    01-01-1998   01-07-2010
# 5363    >10mi                     Other    31-01-2017   01-10-2017
# 5364   5-10mi  Professional Certificate    01-01-2012   01-09-2015
# 5365    2-5mi                     Other    31-01-2008   01-01-2018
#
#       JOBENDDATE     USERID  OVERTIMEHOURS  CHURN
# 0     01-10-2015  870835513             14  False
# 1     01-10-2021   18255040             10   True
# 2           None  813877070              3  False
# 3     01-06-2013  291350804              1  False
# 4           None  580541228              3  False
# ...          ...        ...            ...    ...
# 5361  01-06-2021   59566748              8   True
# 5362  01-04-2013  678853106             10  False
# 5363  01-02-2020  810960945              7  False
# 5364        None   54763409             21  False
# 5365        None  344356384             15  False
#
# [5366 rows x 20 columns]

# %%
print(df.isnull().sum())
# Out:
# SALARY                   0
# SENIORITY                0
# TENUREMONTHS             0
# MONTHSAFTERCOLLEGE       0
# BIRTHYEAR                0
# MAPPEDROLECLEAN          0
# SEX                      0
# ETHNICITY                0
# HOSPITALTYPE             0
# HOSPITALOWNERSHIP        0
# COMPANYNAME              0
# CITYSTATE                0
# DISTANCE                 0
# DEGREECLEAN              0
# SCHOOLENDDATE            0
# JOBSTARTDATE             0
# JOBENDDATE            1610
# USERID                   0
# OVERTIMEHOURS            0
# CHURN                    0
# dtype: int64

# %%
one_uniq = dict()
for col in df.columns:
    if len(df[col].unique()) == 1:
        one_uniq.update({col: df[col].unique().tolist()})
        
print('The name of column(s) with single value: %s' % one_uniq)
# Out:
# The name of column(s) with single value: {'EmployeeCount': [1], 'Over18': ['Y'], 'StandardHours': [80]}

# %%
df.drop(one_uniq.keys(), axis=1, inplace=True)

# %%
df.drop('EmployeeNumber', axis=1, inplace=True)

# %%
education_map = {1: 'Below College', 2: 'College',
                 3: 'Bachelor', 4: 'Master', 5: 'Phd'}
envir_sat_map = {1: 'Low', 2: 'Medium',
                 3: 'High', 4: 'Very High'}
job_inv_map = {1: 'Low', 2: 'Medium',
               3: 'High', 4: 'Very High'}
job_sat_map = {1: 'Low', 2: 'Medium',
               3: 'High', 4: 'Very High'}
perf_rate_map = {1: 'Low', 2: 'Good',
                 3: 'Excellent', 4: 'Outstanding'}
relation_sat_map = {1: 'Low', 2: 'Medium',
                    3: 'High', 4: 'Very High'}
work_life_map = {1: 'Bad', 2: 'Good',
                 3: 'Better', 4: 'Best'}

df['Education'] = df['Education'].apply(lambda x: education_map[x])
df['EnvironmentSatisfaction'] = \
    df['EnvironmentSatisfaction'].apply(lambda x: envir_sat_map[x])
df['JobInvolvement'] = df['JobInvolvement'].apply(lambda x: job_inv_map[x])
df['JobSatisfaction'] = \
df['JobSatisfaction'].apply(lambda x: job_sat_map[x])
df['PerformanceRating'] = df['PerformanceRating'].apply(lambda x: perf_rate_map[x])
df['RelationshipSatisfaction'] = \
    df['RelationshipSatisfaction'].apply(lambda x: relation_sat_map[x])
df['WorkLifeBalance'] = df['WorkLifeBalance'].apply(lambda x: work_life_map[x])

display(df.head(5))
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome      Education EducationField EnvironmentSatisfaction  \
# 0                 1        College  Life Sciences                  Medium
# 1                 8  Below College  Life Sciences                    High
# 2                 2        College          Other               Very High
# 3                 3         Master  Life Sciences               Very High
# 4                 2  Below College        Medical                     Low
#
#    Gender  ...  PerformanceRating RelationshipSatisfaction  StockOptionLevel  \
# 0  Female  ...          Excellent                      Low                 0
# 1    Male  ...        Outstanding                Very High                 1
# 2    Male  ...          Excellent                   Medium                 0
# 3  Female  ...          Excellent                     High                 0
# 4    Male  ...          Excellent                Very High                 1
#
#   TotalWorkingYears TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                 8                     0             Bad               6
# 1                10                     3          Better              10
# 2                 7                     3          Better               0
# 3                 8                     3          Better               8
# 4                 6                     3          Better               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion YearsWithCurrManager
# 0                   4                        0                    5
# 1                   7                        1                    7
# 2                   0                        0                    0
# 3                   7                        3                    0
# 4                   2                        2                    2
#
# [5 rows x 31 columns]

# %%
#Function to augment data by slightly altering values
def augment_data(df, num_desired_records):
    augmented_data = []
    num_existing_records = len(df)
 
    while len(augmented_data) < num_desired_records:
        # Randomly select an existing record
        idx = np.random.randint(num_existing_records)
        original_record = df.iloc[idx].copy()
 
        # Perturb some categorical columns
        original_record['Education'] = np.random.choice(list(education_map.values()))
        original_record['EnvironmentSatisfaction'] = np.random.choice(list(envir_sat_map.values()))
        original_record['JobInvolvement'] = np.random.choice(list(job_inv_map.values()))
        original_record['JobSatisfaction'] = np.random.choice(list(job_sat_map.values()))
        original_record['PerformanceRating'] = np.random.choice(list(perf_rate_map.values()))
        original_record['RelationshipSatisfaction'] = np.random.choice(list(relation_sat_map.values()))
        original_record['WorkLifeBalance'] = np.random.choice(list(work_life_map.values()))
 
        augmented_data.append(original_record)
 
    # Convert list of dictionaries to DataFrame
    augmented_df = pd.DataFrame(augmented_data)
 
    return augmented_df
 
# Example usage to generate 300,000 records
augmented_df = augment_data(df, num_desired_records=300000)
 
# Display the first few rows of the augmented DataFrame
print(augmented_df.head())
# Out:
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 996    27        No  Travel_Rarely        205                   Sales
# 1150   35        No  Travel_Rarely        819  Research & Development
# 859    29        No  Travel_Rarely        942  Research & Development
# 40     35        No  Travel_Rarely        464  Research & Development
# 302    28        No  Travel_Rarely       1476  Research & Development
#
#       DistanceFromHome      Education EducationField EnvironmentSatisfaction  \
# 996                 10  Below College      Marketing                    High
# 1150                18         Master  Life Sciences                    High
# 859                 15         Master  Life Sciences                    High
# 40                   4  Below College          Other               Very High
# 302                 16       Bachelor        Medical               Very High
#
#       Gender  ...  PerformanceRating RelationshipSatisfaction  \
# 996   Female  ...          Excellent                   Medium
# 1150    Male  ...        Outstanding                      Low
# 859   Female  ...          Excellent                   Medium
# 40      Male  ...                Low                Very High
# 302     Male  ...               Good                      Low
#
#       StockOptionLevel TotalWorkingYears TrainingTimesLastYear  \
# 996                  0                 6                     3
# 1150                 0                16                     2
# 859                  1                 6                     2
# 40                   1                 1                     3
# 302                  0                 9                     2
#
#      WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 996             Best               6                   2
# 1150            Good              16                  15
# 859           Better               5                   4
# 40              Good               1                   0
# 302              Bad               8                   3
#
#       YearsSinceLastPromotion YearsWithCurrManager
# 996                         4                    4
# 1150                        1                   10
# 859                         1                    3
# 40                          0                    0
# 302                         0                    7
#
# [5 rows x 31 columns]

# %%
augmented_df.shape
# Out:
# (300000, 31)

# %%
augmented_df.to_csv('HR Employee Attrition2.csv', index=False)
 
#print(f"Augmented dataset saved successfully at: {HR Employee Attrition}")
